# %% [markdown]
# # Siamese network for bearing fault classification
#
# The goal of this notebook is to train a classification model for bearing faults of rotating equipment. We want this model to be robust to different operating conditions, such as different machine loads or rotation velocity. Moreover, the model must not use characteristic information about the machine, such as the rotation velocity or the characteristic coefficients. For this reason, we will follow a Deep Learning approach.
#
# The model consists of a Convolutional Neural Network splitted into two parts:
#
# + **The embedding**: It extracts valuable features from the training data, which will be then fed to the classifier. This embedding is trained using a siamese network, which ensures that the extracted features are robust to different operating conditions.
#
# + **The classifier**: It takes as input the features extracted from the embedding and returns the type of fault of the bearing. It is trained using the typical cross entropy loss.
#
# In this notebook we will train the model using data from two datasets:
#
# + **IMS Nasa Bearing Data Center:** This dataset contains the time evolution of different bearings. At the end of the tests, some of these bearings suffer from faults. The goal of using this dataset is to be able to detect failures at early stages, that is, before they have been fully developed. For this reason, the waveform time series will be labeled using the Autoencoder Model, so that waveforms with early development of the failure will be labeled as being unhealthy. This data will be used in the training phase, so that the classification model will learn to detect early failure modes.
#
# + **Paderborn Data Center**: This dataset also contains vibration data (waveforms) of different bearings, each suffering from a fault (inner ring, outer ring) or being healthy. The fault is completely developed.
#
# We will mix the data from the two datasets in order to have different operating conditions for the different failures.
#
# Waveforms will be used as input for the classification model. Such waveforms will be previously preprocessed. In order to do so, we will apply a rolling window (with no overlap) that will split the long time series into smaller ones of 1000 data points. Also, the waveforms will be downsapled into 5000 Hz, which is the usual sampling frequency of real data. Finally, adaptive normalization will be applied.
#
# More details about the training process are provided in the following sections.

# %% [markdown]
# In the following lines we connect to google drive and to import the needed packages.

# %%
import numpy as np
import pandas as pd
import scipy.io
import matplotlib.pyplot as plt
import sys

import plotly
from plotly.graph_objs import graph_objs as go

from plotly.offline import iplot
from sklearn import metrics

import random


import umap

sys.path.append('./Training')
sys.path.append('./Data')
sys.path.append('./Load_Data')
sys.path.append('./Models')
sys.path.append('./Preprocessing')

from IMS_data import Import_Data_IMS, Preprocessing_IMS
from spectrum import acc_spectrum
from Paderborn_data import Import_Data_Pad, Preprocessing_Pad, Load_Pad
from train_siamese import Bearings_Network
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load Paderborn data
#
# Paderborn data contains time series of the vibration of rotating equipment (bearings). It contains two different rotation speeds (900 rpm and 1500 rpm). The dataset contains data from healthy bearings, and from two different types of faults: inner ring fault and outer ring fault. The faults are completely developed at the beginning of the time series.

# %%
data_Pad = Import_Data_Pad('Data/Paderborn/K001/N15/', 'Data/Paderborn/K001/N09/', 'Data/Paderborn/KI01/N15/', 
                       'Data/Paderborn/KI01/N09/', 'Data/Paderborn/KA01/N15/', 'Data/Paderborn/KA01/N09/')

# %% [markdown]
# ## Preprocessing
#
# In order to preprocess data we performed the following steps:
#
# + Downsampling from 20000 Hz to 5000 Hz in order to have data more similiar to the real productio data.
#
# + Rolling window for each waveform, to reduce the size of the wavevorm to 1000 timestamps (instead of 5000) and to obtain more samples from the same waveform. There is no overlap.
#
# + Adaptative normalization: minmax scaling.
#
# + Adding noise
#
# + Shuffle samples.
#
# + Split of training and test sets.
#
# The noise is introduced in two different ways:
#
# + Amplify the amplitude of the 4rth first harmonics.
#
# + Introduce white noise (random frequencies and amplitudes) within a frequency band of 750-1000Hz.
#
# We add noise so that the data resembles more to real data.

# %% [markdown]
# ### Preprocess Paderborn University Data
#
# Given the file names of the data, the following class imports and processes the data in order to make it suitable for the CNN model.

# %%
#Create preprocessing object
prep = Preprocessing_Pad()

#Load Paderborn data
load_Pad = Load_Pad(prep, data_Pad.healthy_files09, data_Pad.healthy_files15,data_Pad.inner_files09,
                     data_Pad.inner_files15,data_Pad.outer_files09, data_Pad.outer_files15)

X_train_Pad, X_test_Pad, y_train_Pad, y_test_Pad, load_train_Pad, load_test_Pad = load_Pad.get_X_y()
# Out:
# Data/Paderborn/K001/N09/N09_M07_F10_K001_1.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_10.mat
# ./Load_Data\Paderborn_data.py:253: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# ./Load_Data\Paderborn_data.py:255: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# Data/Paderborn/K001/N09/N09_M07_F10_K001_11.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_12.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_13.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_14.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_15.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_16.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_17.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_18.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_19.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_2.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_20.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_3.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_4.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_5.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_6.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_7.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_8.mat
# Data/Paderborn/K001/N09/N09_M07_F10_K001_9.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_1.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_10.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_11.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_12.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_13.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_14.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_15.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_16.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_17.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_18.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_19.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_2.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_20.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_3.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_4.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_5.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_6.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_7.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_8.mat
# Data/Paderborn/K001/N15/N15_M07_F10_K001_9.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_1.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_10.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_11.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_12.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_13.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_14.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_15.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_16.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_17.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_18.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_19.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_2.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_20.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_3.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_4.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_5.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_6.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_7.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_8.mat
# Data/Paderborn/KI01/N09/N09_M07_F10_KI01_9.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_1.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_10.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_11.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_12.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_13.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_14.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_15.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_16.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_17.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_18.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_19.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_2.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_20.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_3.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_4.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_5.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_6.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_7.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_8.mat
# Data/Paderborn/KI01/N15/N15_M07_F10_KI01_9.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_1.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_10.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_11.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_12.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_13.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_14.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_15.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_16.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_17.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_18.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_19.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_2.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_20.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_3.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_4.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_5.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_6.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_7.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_8.mat
# Data/Paderborn/KA01/N09/N09_M07_F10_KA01_9.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_1.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_10.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_11.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_12.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_13.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_14.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_15.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_16.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_17.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_18.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_19.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_2.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_20.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_3.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_4.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_5.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_6.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_7.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_8.mat
# Data/Paderborn/KA01/N15/N15_M07_F10_KA01_9.mat

# %% [markdown]
# ## Visualizing the noise
#
# We have mentioned that we have added noise to the Paderborn dataset so that it resembles more the real data. In the following code, we will give an example to show what the noise looks like, both in the time (waveform) and frequency (spectrum) domain.

# %%
#Prepare the data
file_name = data_Pad.normal_files15[1]
mat_dict = scipy.io.loadmat(file_name)
try:
    healthy = mat_dict[file_name[24:43]]['Y'][0][0][0][6][2][0]
except:
    healthy = mat_dict[file_name[24:42]]['Y'][0][0][0][6][2][0]
healthy = scipy.signal.decimate(healthy, 12)  # Downsampling to 5000 Hz
vel = float(file_name[21:23])

data = np.copy(healthy)

#Prepare the noise and added noise
noise = np.zeros(data.shape)
noise = prep.add_noise_harmonics(noise,vel)
noise = prep.add_noise_band(noise,300000,20000,0,0.08,10,4.0)
data_noise = data + noise

#Show plots

#Spectrum of signal
fft_env, freqs_env, _ = acc_spectrum(data, len(data), 5000, cutoff_freq=1)
plt.title('Spectrum of signal')
plt.ylim(0,0.1)
plt.plot(freqs_env, fft_env)
plt.show()

#Spectrum of noise
fft_noise, freqs_noise, _ = acc_spectrum(noise, len(noise), 5000, cutoff_freq=1)
plt.plot(freqs_noise, fft_noise)
plt.title('Spectrum of noise')
plt.show()

#Spectrum of signal+noise
fft_env, freqs_env, _ = acc_spectrum(data_noise, len(data_noise), 5000, cutoff_freq=1)
plt.title('Spectrum of signal+noise')
plt.plot(freqs_env, fft_env)
plt.show()

#Waveform of signal
plt.plot(range(len(data[range(100,2000,5)])),data[range(100,2000,5)])
plt.title('Waveform of signal')
plt.show()

#Waveform of noise
plt.plot(range(len(noise[range(100,2000,5)])),noise[range(100,2000,5)])
plt.title('Waveform of noise')
plt.show()

#Waveform of signal+noise
plt.plot(range(len(data_noise[range(100,2000,5)])),data_noise[range(100,2000,5)])
plt.title('Waveform of signal+noise')
plt.show()

# %% [markdown]
# ## Import IMS Data
#
# We import the two files from the IMS Nasa Bearing Data Center.
# The datasets consist of two tests (Test1 and Test2), which contain the waveform time evolution of four bearings. Vibration data is collected with accelerometers. The bearings are of type Rexnord ZA-2115​.
#
# The final state of each of the bearings is the following:
#
# **Test1:**
# + Bearing 1 has an outer race defect which starts at around timestep 800
# + Bearing 2 is healthy
# + Bearing 3 is healthy
# + Bearing 4 has a rolling defect which starts at around timestamp 1800
#
# **Test2:**
# + Bearing 1 is healthy
# + Bearing 2 is healthy
# + Bearing 3 has an inner race defect which starts at around timestep 1800
# + Bearing 4 is healthy
#
#
# In the following class we will import the data from csv files and split it into four dataframes, one for each bearing.

# %%
test1 = Import_Data_IMS('Data/IMS/Test_1.csv')
test2 = Import_Data_IMS('Data/IMS/Test_2.csv')

# %% [markdown]
# The following lines of code put split the data into being healthy or having a failure (inner ring failure, outer ring failure and rolling element failure). In order to do wo, we use the labels obtained from the Autoencoder model, which tell us approximately in which timestamp the errors start their development.

# %%
#Define unhealthy data using the labels from the autoencoder model
inner = test1.t_2[1800:,:]
outer = test2.t_0[800:,:]
rolling = test1.t_3[1800:,:]

#For the healthy data, use waveforms from all tests
#We use a balanced dataset for healthy/unealthy data
idx = np.random.choice(np.arange(1300),70)
healthy1 = test1.t_2[idx,:]
idx = np.random.choice(np.arange(1300),70)
healthy2 = test1.t_3[idx,:]
idx = np.random.choice(np.arange(300),70)
healthy3 = test2.t_0[idx,:]

#Finally, concatenate all the healthy data
healthy  = np.concatenate([healthy1,healthy2,healthy3])

# %% [markdown]
# ## Preprocessing IMS Data
#
# In order to preprocess data we performed the following steps:
#
# + Downsampling from 20000 Hz to 5000 Hz in order to have data more similiar to the real productio data.
#
# + Rolling window for each waveform, to reduce the size of the wavevorm to 1000 timestamps (instead of 5000) and to obtain more samples from the same waveform. There is no overlap.
#
# + Adaptative normalization: minmax scaling.
#
# + Shuffle samples.
#
# + Split of training and test sets.

# %%
prep_IMS = Preprocessing_IMS(inner, outer, rolling, healthy)

X_train_IMS, X_test_IMS, y_train_IMS, y_test_IMS = prep_IMS.get_X_y()

# %% [markdown]
# ## Join datasets

# %%
X_train = np.concatenate((X_train_Pad, X_train_IMS), axis=0)
X_test = np.concatenate((X_test_Pad, X_test_IMS), axis=0) 

y_train = np.concatenate((y_train_Pad, y_train_IMS), axis=0) 
y_test = np.concatenate((y_test_Pad,  y_test_IMS), axis=0) 

load_train = np.concatenate((load_train_Pad,  np.repeat(6, y_train_IMS.shape[0])), axis=0)
load_test = np.concatenate((load_test_Pad,  np.repeat(6, y_test_IMS.shape[0])), axis=0)

# %% [markdown]
# Mix everything

# %%
#Shuffle indeces so that the loads/defects are not ordered
idx = np.arange(X_train.shape[0])
np.random.shuffle(idx)
X_train = X_train[idx,:]
y_train = y_train[idx]
load_train = load_train[idx]

idx = np.arange(X_test.shape[0])
np.random.shuffle(idx)
X_test = X_test[idx,:]
y_test = y_test[idx]
load_test = load_test[idx]

# %% [markdown]
# ## Siamese Network
#
# (based on: https://github.com/DataScienceUB/DeepLearningMaster20192020/blob/master/5.%20Keras.ipynb and  https://github.com/fchollet/keras/blob/master/examples/mnist_siamese_graph.py)
#
# The goal of the Siamese network is to create useful embeddings for data points. In our case, the network will learn to map a waveform signal to a point in a lower dimensional space, while trying to minimize the distance between points of the same class and maximize the distance between points of different classes.
#
#
#
# Let $X_1$ and $X_2$ be two waveform samples. We feed these samples into the feature network $G_W$ and compute corresponding feature vectors $G_W(X_1)$ and $G_W(X_2)$. The final layer computes pair-wise distance between computed features $E_W = || G_W(X_1) - G_W(X_2) ||_{1}$ and final loss layer $L$ considers whether these two images are from the same class (label $ Y = 1$) or not (label $Y = 0$).
#
# ![alt text](https://github.com/DataScienceUB/DeepLearningMaster2019/blob/master/images/siamese1.png?raw=1)
#
#
# The goal is that $E_W$  is small if $X_1$ and $X_2$ belong to the same class ($Y=1$), and large if they belong to different classes ($Y=0$). The system is trained on pairs of patterns $(X_1,X_2)$ taken from a training set.  The loss function minimized by training minimizes $E_W(X_1, X_2)$ when $X_1$ and $X_2$ are from the same class, and maximizes $E_W(X_1, X_2)$ when they belong to different classes. Note that the same neural network $G_W$ (with the same weights) is used for the two members of the pair $X_1$ and $X_2$. For this reason, the network is called siamese network.
#
# At first glance, we might think that simply minimizing $E_W(X_1, X_2)$ averaged over a set of pairs of inputs from the same class would be sufficient. But this generally leads to a catastrophic collapse: The loss function $\mathcal{L}$ can be made zero by simply making $E_W(X_1, X_2)$ a constant function. Therefore, the loss function needs a contrastive term to ensure not only that the distance $E_W$ for a pair of inputs from the same class is low, but also that the distance $E_W$ for a pair from different classes is large.
#
# In the original [paper](http://yann.lecun.com/exdb/publis/pdf/chopra-05.pdf) it was proposed the **Contrastive Loss Function**:
#
#
#
# $$
# L(W,(Y,X_1,X_2)^i) = (1 - Y) \times L_S(E_W(X_1,X_2)^i) + Y \times L_D(E_W(X_1,X_2)^i)
# $$
#
# where $L_S$ is the partial loss function for a "same-class" pair and $L_D$ is the partial loss function for a "different-class" pair.
#
# $L_S$ and $L_D$ should be designed in such a way that the minimization of $L$ will decrease the distance in the embedding space of "same-class" pairs and increase it in the case of "different-class" pairs. A simple way to achieve this property is to make $\mathcal{L}_S$ monotonically increasing with $E_W$, and $\mathcal{L}_D$ monotonically decreasing with $E_W$.
#
# $$ L_S = \frac{1}{2} E_W^2 $$
# $$ L_D = \frac{1}{2} \{ \mbox{max }(0,1-E_W) \}^2 $$
#
#
# **References**:
#
# Jordi Vitrià. *Deep Learning Master Repository*. https://github.com/DataScienceUB/DeepLearningMaster20192020/blob/master/. 2019
#
# S. Chopra, R. Hadsell, and Y. LeCun. *Learning a similarity metric discrimi-natively, with application to face verification*. In: 2005 IEEE Computer Society Conference on Computer Vision and Pattern Recognition (CVPR’05). 2005, 539–546vol. DOI: 10.1109/CVPR.2005.202

# %% [markdown]
# ### Design of the CNN
#
# In order to design a Siamese network, we will use a 1D convolutional neural network as the embedding network. Then, we will add some fully connected layers that will classify the bearing faults based on the embeddings extracted by the CNN. This network will be trained using the contrastive loss function and also the cross entropy loss for classifications.
#
#
# The CNN has 3 1D Convolutional layers with 32 filters, height=10, strides=1 and padding='same'. We have 3 MaxPooling subsampling layers with pool size = 20, strides = 4. Then we have 1 FC with 256 nodes, one with 128 nodes, and another with 20 output nodes.  All other layers have Relu activation function. This network will extract the embeddings. The classification layer will be a softmax layer with 4 outputs.
#
# We will first pretrain the network using only the classification loss. The performance of this pretrained network will be used as a baseline and will be compared with the same network trained using also contrastive loss. The following class defines the network and allows pretraining and training.
#
# The following cell pre-trains the CNN model. You can omit this cell and load the saved weights. The training may take some time (around 20min), especially if not using GPU.

# %%
pretrain = Bearings_Network(type_net="Pretrain")
pretrain.fit( X_train, y_train, load_train,X_test, y_test, load_test,20, prop =1, save=True,
             patience=10, filepath = "Weights/Siamese/Pretrain.h5", filepath_base = "Weights/Siamese/Pretrain_base.h5")
# Out:
# Creating  Pretrain  Network
# Train on 8120 samples, validate on 4712 samples
# Epoch 1/20
# 8120/8120 [==============================] - 46s 6ms/sample - loss: 1.3526 - categorical_accuracy: 0.3238 - val_loss: 1.2264 - val_categorical_accuracy: 0.4219
# Epoch 2/20
# 8120/8120 [==============================] - 44s 5ms/sample - loss: 1.1717 - categorical_accuracy: 0.4330 - val_loss: 1.0551 - val_categorical_accuracy: 0.4788
# Epoch 3/20
# 8120/8120 [==============================] - 47s 6ms/sample - loss: 1.0626 - categorical_accuracy: 0.4762 - val_loss: 0.9755 - val_categorical_accuracy: 0.4813
# Epoch 4/20
# 8120/8120 [==============================] - 44s 5ms/sample - loss: 0.9850 - categorical_accuracy: 0.5176 - val_loss: 0.8857 - val_categorical_accuracy: 0.5327
# Epoch 5/20
# 8120/8120 [==============================] - 44s 5ms/sample - loss: 0.8894 - categorical_accuracy: 0.5717 - val_loss: 0.7510 - val_categorical_accuracy: 0.6621
# Epoch 6/20
# 8120/8120 [==============================] - 44s 5ms/sample - loss: 0.7775 - categorical_accuracy: 0.6325 - val_loss: 0.7109 - val_categorical_accuracy: 0.6430
# Epoch 7/20
# 8120/8120 [==============================] - 47s 6ms/sample - loss: 0.6927 - categorical_accuracy: 0.6776 - val_loss: 0.5501 - val_categorical_accuracy: 0.7721
# Epoch 8/20
# 8120/8120 [==============================] - 44s 5ms/sample - loss: 0.6392 - categorical_accuracy: 0.7161 - val_loss: 0.5024 - val_categorical_accuracy: 0.7835
# Epoch 9/20
# 8120/8120 [==============================] - 44s 5ms/sample - loss: 0.5927 - categorical_accuracy: 0.7317 - val_loss: 0.5137 - val_categorical_accuracy: 0.7479
# Epoch 10/20
# 8120/8120 [==============================] - 44s 5ms/sample - loss: 0.5477 - categorical_accuracy: 0.7575 - val_loss: 0.3993 - val_categorical_accuracy: 0.8328
# Epoch 11/20
# 8120/8120 [==============================] - 45s 6ms/sample - loss: 0.4976 - categorical_accuracy: 0.7835 - val_loss: 0.3537 - val_categorical_accuracy: 0.8663
# Epoch 12/20
# 8120/8120 [==============================] - 44s 5ms/sample - loss: 0.4478 - categorical_accuracy: 0.8057 - val_loss: 0.3072 - val_categorical_accuracy: 0.8769
# Epoch 13/20
# 8120/8120 [==============================] - 44s 5ms/sample - loss: 0.3987 - categorical_accuracy: 0.8272 - val_loss: 0.2712 - val_categorical_accuracy: 0.9041
# Epoch 14/20
# 8120/8120 [==============================] - 46s 6ms/sample - loss: 0.3637 - categorical_accuracy: 0.8437 - val_loss: 0.2273 - val_categorical_accuracy: 0.9181
# Epoch 15/20
# 8120/8120 [==============================] - 47s 6ms/sample - loss: 0.3423 - categorical_accuracy: 0.8552 - val_loss: 0.2257 - val_categorical_accuracy: 0.9049
# Epoch 16/20
# 8120/8120 [==============================] - 46s 6ms/sample - loss: 0.3190 - categorical_accuracy: 0.8654 - val_loss: 0.2010 - val_categorical_accuracy: 0.9117
# Epoch 17/20
# 8120/8120 [==============================] - 45s 6ms/sample - loss: 0.3068 - categorical_accuracy: 0.8697 - val_loss: 0.2328 - val_categorical_accuracy: 0.9020
# Epoch 18/20
# 8120/8120 [==============================] - 45s 6ms/sample - loss: 0.2882 - categorical_accuracy: 0.8786 - val_loss: 0.1952 - val_categorical_accuracy: 0.9202
# Epoch 19/20
# 8120/8120 [==============================] - 43s 5ms/sample - loss: 0.2859 - categorical_accuracy: 0.8791 - val_loss: 0.1735 - val_categorical_accuracy: 0.9291
# Epoch 20/20
# 8120/8120 [==============================] - 43s 5ms/sample - loss: 0.2645 - categorical_accuracy: 0.8900 - val_loss: 0.1833 - val_categorical_accuracy: 0.9232
# Saved model to disk

# %%
# Comment these lines if you don't want to load the saved weights

pretrain = Bearings_Network(type_net="Pretrain")
pretrain.load_weights(filepath = "Weights/Siamese/Pretrain.h5", filepath_base = "Weights/Siamese/Pretrain_base.h5", 
                      type_net = "Pretrain" )
# Out:
# Creating  Pretrain  Network
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %% [markdown]
# Create Test data

# %%
#Test
testX= np.expand_dims(X_test, axis=2)

y_pred = pretrain.model.predict([testX])

# %% [markdown]
# Check confusion matrix

# %%
matrix = metrics.confusion_matrix(y_test, y_pred.argmax(axis=1))
print("Confusion matrix: \n" + str(matrix))
print("Accuracy: " + str(np.sum(np.diag(matrix))/np.sum(matrix)))
# Out:
# Confusion matrix:
# [[574 175   1   0]
#  [ 23 734   0 233]
#  [303   3 397   2]
#  [  0   5   0 585]]
# Accuracy: 0.7545304777594728

# %% [markdown]
# We observe that the pretraining accuracy is quite good, even though it can be improved.

# %% [markdown]
# ## Visualization of embeddings: UMAP
#
# We perform a UMAP to visualize the embeddings extracted from the embedding model.
#
# UMAP is a new technique by McInnes et al. that offers a number of advantages over t-SNE, most notably increased speed and better preservation of the data's global structure. Here we give a glimpse of what this technique does.
#
# ### UMAP algorithm
#
# In its simplest sense, the UMAP algorithm consists of two steps: construction of a graph in high dimensions followed by an optimization step to find the most similar graph in lower dimensions.
#
# + **Step 1: Constructing the high-dimensional graph**: We start by considering our data in a continuous high dimensional space. To determine connectedness, UMAP extends a radius outwards from each point, connecting points when those radii overlap. hoosing this radius is critical - too small a choice will lead to small, isolated clusters, while too large a choice will connect everything together. UMAP overcomes this challenge by choosing a radius locally, based on the distance to each point's nth nearest neighbor. Within this local radius, connectedness is then made “fuzzy” by making each connection a probability, with further points less likely to be connected. Since we don’t want any points to be completely isolated, a constraint is added that all points must be connected to at least its closest neighboring point. The final output of this process is a weighted graph, with edge weights representing the likelihood that two points are “connected” in our high-dimensional manifold.
#
# + **Step 2: Constructing the low-dimensional graph**: Ideally we want the low dimensional representation to have as similar a fuzzy topological structure as possible. The edges weights between nodes were interpreted as the probability of having a connection. Thus, since both topological structures we are comparing share the same number of nodes, we can imagine that we are comparing the two vectors of probabilities. Given that these are Bernoulli variables (ultimately a connection either exists or it does not, and its probability is the parameter of a Bernoulli distribution), the right choice here is the cross entropy between the weights vectors of the high and low graphs. Therefore, this second phase consists of optimizing the low dimensional graph in terms of the cross entropy measure.
#
#
# ### UMAP parameters
#
# Now we describe the hyperparameters of the algorithm:
#
# + **n_neighbors**: the number of nearest neighbors used to construct the initial high-dimensional graph. It effectively controls how UMAP balances local versus global structure - low values will push UMAP to focus more on local structure by constraining the number of neighboring points considered when analyzing the data in high dimensions, while high values will push UMAP towards representing the big-picture structure while losing fine detail.
#
# + **min_dist**: the minimum distance between points in low-dimensional space. This parameter controls how tightly UMAP clumps points together, with low values leading to more tightly packed embeddings. Larger values of min_dist will make UMAP pack points together more loosely, focusing instead on the preservation of the broad topological structure.
#
# **References**:
#
# High-level explanation:
#
# + Adam Pearce Andy Coenen. *Understanding UMAP*. URL:https://pair-code.github.io/understanding-umap/
#
# + *How UMAP Works*. URL: https://umap-learn.readthedocs.io/en/latest/how_umap_works.html
#
# Original paper:
#
# + Leland  McInnes,  John  Healy,  and  James  Melville. *UMAP:  Uniform  ManifoldApproximation  and  Projection  for  Dimension  Reduction*. URL: https://arxiv.org/pdf/1802.03426.

# %%
features = pretrain.base_network.predict(testX)

embedding = umap.UMAP(n_neighbors=5,
                      min_dist=0.9,
                      metric='correlation').fit_transform(features)

color = pd.DataFrame(y_test,columns=['color'])
color.replace({0:'red', 1:'blue', 2:'green', 3: 'purple'},inplace=True)


fig, ax = plt.subplots(figsize=(10, 8))
plt.scatter(embedding[:,0], embedding[:,1], 
            c=color.values.flatten(),
            cmap="Spectral", 
            s=1.0)
plt.setp(ax, xticks=[], yticks=[])
plt.title("Extracted features classification model", fontsize=18)

plt.show()
# Out:
# C:\Users\laia.domingo.colomer\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\spectral.py:229: UserWarning:
#
# Embedding a total of 10 separate connected components using meta-embedding (experimental)

# %% [markdown]
# Te previous figure shows that the embeddings are quite separate. This means that the cross entropy loss already generates good embeddings. We will train the model using Contrastive loss and see if we can improve these embeddings.
#
# Again, you can omit this cell and load the saved weights. The training may take a couple of hours, if not using GPU.

# %%
# Comment these lines if you don't want to use the saved weights
siamese= Bearings_Network(type_net="Siamese", base_network = pretrain.base_network)

siamese.fit( X_train, y_train, load_train, X_test, y_test, load_test, 150, patience=10, 
            filepath = "Weights/Siamese/Siamese.h5", filepath_base = "Weights/Siamese/Siamese_base.h5")
# Out:
# Creating  Siamese  Network
# Train on 8120 samples, validate on 4712 samples
# Epoch 1/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 5.2081 - lambda_5_loss: 0.2471 - dense_13_loss: 1.3696 - dense_14_loss: 1.3670 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.3884 - dense_14_categorical_accuracy: 0.4021 - val_loss: 4.8014 - val_lambda_5_loss: 0.2123 - val_dense_13_loss: 1.3375 - val_dense_14_loss: 1.3329 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.4932 - val_dense_14_categorical_accuracy: 0.5134
# Epoch 2/150
# 8120/8120 [==============================] - 50s 6ms/sample - loss: 4.5255 - lambda_5_loss: 0.1920 - dense_13_loss: 1.3043 - dense_14_loss: 1.3011 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.5909 - dense_14_categorical_accuracy: 0.5400 - val_loss: 3.7366 - val_lambda_5_loss: 0.1226 - val_dense_13_loss: 1.2532 - val_dense_14_loss: 1.2507 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.8060 - val_dense_14_categorical_accuracy: 0.6273
# Epoch 3/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 3.9811 - lambda_5_loss: 0.1553 - dense_13_loss: 1.2144 - dense_14_loss: 1.2140 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.7490 - dense_14_categorical_accuracy: 0.7261 - val_loss: 3.4183 - val_lambda_5_loss: 0.1089 - val_dense_13_loss: 1.1630 - val_dense_14_loss: 1.1602 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.8438 - val_dense_14_categorical_accuracy: 0.8463
# Epoch 4/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 3.6380 - lambda_5_loss: 0.1422 - dense_13_loss: 1.1091 - dense_14_loss: 1.1067 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.7919 - dense_14_categorical_accuracy: 0.7895 - val_loss: 3.0440 - val_lambda_5_loss: 0.0914 - val_dense_13_loss: 1.0645 - val_dense_14_loss: 1.0628 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.8625 - val_dense_14_categorical_accuracy: 0.8608
# Epoch 5/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 3.3454 - lambda_5_loss: 0.1345 - dense_13_loss: 0.9993 - dense_14_loss: 1.0009 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.8232 - dense_14_categorical_accuracy: 0.8186 - val_loss: 2.4817 - val_lambda_5_loss: 0.0698 - val_dense_13_loss: 0.8904 - val_dense_14_loss: 0.8888 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9126 - val_dense_14_categorical_accuracy: 0.9077
# Epoch 6/150
# 8120/8120 [==============================] - 56s 7ms/sample - loss: 2.9847 - lambda_5_loss: 0.1222 - dense_13_loss: 0.8818 - dense_14_loss: 0.8798 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.8659 - dense_14_categorical_accuracy: 0.8682 - val_loss: 1.9864 - val_lambda_5_loss: 0.0425 - val_dense_13_loss: 0.7801 - val_dense_14_loss: 0.7788 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9482 - val_dense_14_categorical_accuracy: 0.9469
# Epoch 7/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 2.5927 - lambda_5_loss: 0.1055 - dense_13_loss: 0.7710 - dense_14_loss: 0.7669 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.8937 - dense_14_categorical_accuracy: 0.8947 - val_loss: 2.1253 - val_lambda_5_loss: 0.0653 - val_dense_13_loss: 0.7363 - val_dense_14_loss: 0.7364 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.8956 - val_dense_14_categorical_accuracy: 0.8941
# Epoch 8/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 2.4470 - lambda_5_loss: 0.1054 - dense_13_loss: 0.6991 - dense_14_loss: 0.6940 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.8901 - dense_14_categorical_accuracy: 0.8882 - val_loss: 1.8775 - val_lambda_5_loss: 0.0545 - val_dense_13_loss: 0.6648 - val_dense_14_loss: 0.6658 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9202 - val_dense_14_categorical_accuracy: 0.9181
# Epoch 9/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 2.2271 - lambda_5_loss: 0.0988 - dense_13_loss: 0.6211 - dense_14_loss: 0.6185 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9037 - dense_14_categorical_accuracy: 0.9041 - val_loss: 1.3412 - val_lambda_5_loss: 0.0297 - val_dense_13_loss: 0.5212 - val_dense_14_loss: 0.5212 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9718
# Epoch 10/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 1.9575 - lambda_5_loss: 0.0899 - dense_13_loss: 0.5323 - dense_14_loss: 0.5260 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9196 - dense_14_categorical_accuracy: 0.9238 - val_loss: 1.3325 - val_lambda_5_loss: 0.0358 - val_dense_13_loss: 0.4872 - val_dense_14_loss: 0.4841 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9626 - val_dense_14_categorical_accuracy: 0.9629
# Epoch 11/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 1.9472 - lambda_5_loss: 0.0941 - dense_13_loss: 0.5018 - dense_14_loss: 0.5043 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9129 - dense_14_categorical_accuracy: 0.9128 - val_loss: 1.2629 - val_lambda_5_loss: 0.0370 - val_dense_13_loss: 0.4452 - val_dense_14_loss: 0.4453 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9546 - val_dense_14_categorical_accuracy: 0.9542
# Epoch 12/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 1.8759 - lambda_5_loss: 0.0936 - dense_13_loss: 0.4678 - dense_14_loss: 0.4716 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9200 - dense_14_categorical_accuracy: 0.9200 - val_loss: 1.1283 - val_lambda_5_loss: 0.0333 - val_dense_13_loss: 0.3974 - val_dense_14_loss: 0.3959 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9648 - val_dense_14_categorical_accuracy: 0.9643
# Epoch 13/150
# 8120/8120 [==============================] - 55s 7ms/sample - loss: 1.8092 - lambda_5_loss: 0.0941 - dense_13_loss: 0.4288 - dense_14_loss: 0.4390 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9333 - dense_14_categorical_accuracy: 0.9278 - val_loss: 1.0102 - val_lambda_5_loss: 0.0288 - val_dense_13_loss: 0.3590 - val_dense_14_loss: 0.3608 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9758 - val_dense_14_categorical_accuracy: 0.9752
# Epoch 14/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 1.6596 - lambda_5_loss: 0.0882 - dense_13_loss: 0.3882 - dense_14_loss: 0.3893 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9484 - dense_14_categorical_accuracy: 0.9491 - val_loss: 0.8015 - val_lambda_5_loss: 0.0218 - val_dense_13_loss: 0.2901 - val_dense_14_loss: 0.2919 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9809 - val_dense_14_categorical_accuracy: 0.9803
# Epoch 15/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 1.5239 - lambda_5_loss: 0.0827 - dense_13_loss: 0.3500 - dense_14_loss: 0.3472 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9528 - dense_14_categorical_accuracy: 0.9568 - val_loss: 0.8263 - val_lambda_5_loss: 0.0248 - val_dense_13_loss: 0.2875 - val_dense_14_loss: 0.2894 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9690 - val_dense_14_categorical_accuracy: 0.9701
# Epoch 16/150
# 8120/8120 [==============================] - 55s 7ms/sample - loss: 1.4766 - lambda_5_loss: 0.0817 - dense_13_loss: 0.3278 - dense_14_loss: 0.3316 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9549 - dense_14_categorical_accuracy: 0.9512 - val_loss: 0.8587 - val_lambda_5_loss: 0.0303 - val_dense_13_loss: 0.2775 - val_dense_14_loss: 0.2795 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9686 - val_dense_14_categorical_accuracy: 0.9684
# Epoch 17/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 1.5107 - lambda_5_loss: 0.0856 - dense_13_loss: 0.3247 - dense_14_loss: 0.3307 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9454 - dense_14_categorical_accuracy: 0.9429 - val_loss: 0.7982 - val_lambda_5_loss: 0.0288 - val_dense_13_loss: 0.2536 - val_dense_14_loss: 0.2552 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9724 - val_dense_14_categorical_accuracy: 0.9718
# Epoch 18/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 1.3152 - lambda_5_loss: 0.0758 - dense_13_loss: 0.2810 - dense_14_loss: 0.2764 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9608 - dense_14_categorical_accuracy: 0.9650 - val_loss: 0.7718 - val_lambda_5_loss: 0.0292 - val_dense_13_loss: 0.2382 - val_dense_14_loss: 0.2400 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9699 - val_dense_14_categorical_accuracy: 0.9690
# Epoch 19/150
# 8120/8120 [==============================] - 53s 6ms/sample - loss: 1.3010 - lambda_5_loss: 0.0773 - dense_13_loss: 0.2656 - dense_14_loss: 0.2620 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9621 - dense_14_categorical_accuracy: 0.9634 - val_loss: 0.6822 - val_lambda_5_loss: 0.0252 - val_dense_13_loss: 0.2137 - val_dense_14_loss: 0.2153 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9716 - val_dense_14_categorical_accuracy: 0.9716
# Epoch 20/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 1.1600 - lambda_5_loss: 0.0695 - dense_13_loss: 0.2290 - dense_14_loss: 0.2354 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9748 - dense_14_categorical_accuracy: 0.9730 - val_loss: 0.5253 - val_lambda_5_loss: 0.0186 - val_dense_13_loss: 0.1682 - val_dense_14_loss: 0.1701 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9834 - val_dense_14_categorical_accuracy: 0.9837
# Epoch 21/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 1.1363 - lambda_5_loss: 0.0700 - dense_13_loss: 0.2198 - dense_14_loss: 0.2170 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9718 - dense_14_categorical_accuracy: 0.9762 - val_loss: 0.5688 - val_lambda_5_loss: 0.0226 - val_dense_13_loss: 0.1696 - val_dense_14_loss: 0.1717 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9826 - val_dense_14_categorical_accuracy: 0.9811
# Epoch 22/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 1.1976 - lambda_5_loss: 0.0741 - dense_13_loss: 0.2275 - dense_14_loss: 0.2285 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9698 - dense_14_categorical_accuracy: 0.9693 - val_loss: 0.8626 - val_lambda_5_loss: 0.0389 - val_dense_13_loss: 0.2337 - val_dense_14_loss: 0.2369 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9580 - val_dense_14_categorical_accuracy: 0.9576
# Epoch 23/150
# 8120/8120 [==============================] - 53s 6ms/sample - loss: 1.2672 - lambda_5_loss: 0.0793 - dense_13_loss: 0.2417 - dense_14_loss: 0.2332 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9570 - dense_14_categorical_accuracy: 0.9621 - val_loss: 0.7089 - val_lambda_5_loss: 0.0322 - val_dense_13_loss: 0.1921 - val_dense_14_loss: 0.1930 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9639 - val_dense_14_categorical_accuracy: 0.9637
# Epoch 24/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 1.1089 - lambda_5_loss: 0.0704 - dense_13_loss: 0.2062 - dense_14_loss: 0.1987 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9670 - dense_14_categorical_accuracy: 0.9701 - val_loss: 0.5689 - val_lambda_5_loss: 0.0256 - val_dense_13_loss: 0.1539 - val_dense_14_loss: 0.1571 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9805 - val_dense_14_categorical_accuracy: 0.9790
# Epoch 25/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 1.0332 - lambda_5_loss: 0.0674 - dense_13_loss: 0.1786 - dense_14_loss: 0.1809 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9767 - dense_14_categorical_accuracy: 0.9761 - val_loss: 0.5394 - val_lambda_5_loss: 0.0248 - val_dense_13_loss: 0.1439 - val_dense_14_loss: 0.1459 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9805 - val_dense_14_categorical_accuracy: 0.9809
# Epoch 26/150
# 8120/8120 [==============================] - 55s 7ms/sample - loss: 0.9371 - lambda_5_loss: 0.0630 - dense_13_loss: 0.1536 - dense_14_loss: 0.1533 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9840 - dense_14_categorical_accuracy: 0.9855 - val_loss: 0.6072 - val_lambda_5_loss: 0.0281 - val_dense_13_loss: 0.1620 - val_dense_14_loss: 0.1617 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9724 - val_dense_14_categorical_accuracy: 0.9728
# Epoch 27/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.9255 - lambda_5_loss: 0.0632 - dense_13_loss: 0.1466 - dense_14_loss: 0.1473 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9861 - dense_14_categorical_accuracy: 0.9845 - val_loss: 0.7035 - val_lambda_5_loss: 0.0361 - val_dense_13_loss: 0.1709 - val_dense_14_loss: 0.1698 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9686 - val_dense_14_categorical_accuracy: 0.9694
# Epoch 28/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.9079 - lambda_5_loss: 0.0620 - dense_13_loss: 0.1464 - dense_14_loss: 0.1418 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9836 - dense_14_categorical_accuracy: 0.9828 - val_loss: 0.5497 - val_lambda_5_loss: 0.0264 - val_dense_13_loss: 0.1407 - val_dense_14_loss: 0.1431 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9771 - val_dense_14_categorical_accuracy: 0.9767
# Epoch 29/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.8483 - lambda_5_loss: 0.0599 - dense_13_loss: 0.1258 - dense_14_loss: 0.1231 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9898 - dense_14_categorical_accuracy: 0.9915 - val_loss: 0.4860 - val_lambda_5_loss: 0.0240 - val_dense_13_loss: 0.1226 - val_dense_14_loss: 0.1222 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9817 - val_dense_14_categorical_accuracy: 0.9817
# Epoch 30/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.9612 - lambda_5_loss: 0.0661 - dense_13_loss: 0.1523 - dense_14_loss: 0.1475 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9781 - dense_14_categorical_accuracy: 0.9794 - val_loss: 0.6739 - val_lambda_5_loss: 0.0352 - val_dense_13_loss: 0.1588 - val_dense_14_loss: 0.1611 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9643 - val_dense_14_categorical_accuracy: 0.9637
# Epoch 31/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.8368 - lambda_5_loss: 0.0598 - dense_13_loss: 0.1185 - dense_14_loss: 0.1209 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9894 - dense_14_categorical_accuracy: 0.9863 - val_loss: 0.5640 - val_lambda_5_loss: 0.0293 - val_dense_13_loss: 0.1341 - val_dense_14_loss: 0.1356 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9707 - val_dense_14_categorical_accuracy: 0.9707
# Epoch 32/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.9465 - lambda_5_loss: 0.0660 - dense_13_loss: 0.1436 - dense_14_loss: 0.1428 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9777 - dense_14_categorical_accuracy: 0.9791 - val_loss: 0.6724 - val_lambda_5_loss: 0.0375 - val_dense_13_loss: 0.1467 - val_dense_14_loss: 0.1488 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9686 - val_dense_14_categorical_accuracy: 0.9675
# Epoch 33/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.8313 - lambda_5_loss: 0.0607 - dense_13_loss: 0.1111 - dense_14_loss: 0.1128 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9873 - dense_14_categorical_accuracy: 0.9885 - val_loss: 0.5679 - val_lambda_5_loss: 0.0303 - val_dense_13_loss: 0.1299 - val_dense_14_loss: 0.1328 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9694 - val_dense_14_categorical_accuracy: 0.9690
# Epoch 34/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.8045 - lambda_5_loss: 0.0587 - dense_13_loss: 0.1099 - dense_14_loss: 0.1081 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9865 - dense_14_categorical_accuracy: 0.9879 - val_loss: 0.4973 - val_lambda_5_loss: 0.0268 - val_dense_13_loss: 0.1125 - val_dense_14_loss: 0.1152 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9784 - val_dense_14_categorical_accuracy: 0.9777
# Epoch 35/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.7656 - lambda_5_loss: 0.0566 - dense_13_loss: 0.1023 - dense_14_loss: 0.0977 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9887 - dense_14_categorical_accuracy: 0.9892 - val_loss: 0.5054 - val_lambda_5_loss: 0.0272 - val_dense_13_loss: 0.1145 - val_dense_14_loss: 0.1180 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9784 - val_dense_14_categorical_accuracy: 0.9764
# Epoch 36/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.7246 - lambda_5_loss: 0.0544 - dense_13_loss: 0.0904 - dense_14_loss: 0.0904 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9930 - dense_14_categorical_accuracy: 0.9913 - val_loss: 0.5698 - val_lambda_5_loss: 0.0315 - val_dense_13_loss: 0.1253 - val_dense_14_loss: 0.1280 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9775 - val_dense_14_categorical_accuracy: 0.9775
# Epoch 37/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.7470 - lambda_5_loss: 0.0570 - dense_13_loss: 0.0891 - dense_14_loss: 0.0882 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9926 - dense_14_categorical_accuracy: 0.9917 - val_loss: 0.6120 - val_lambda_5_loss: 0.0340 - val_dense_13_loss: 0.1338 - val_dense_14_loss: 0.1367 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9707 - val_dense_14_categorical_accuracy: 0.9701
# Epoch 38/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.7800 - lambda_5_loss: 0.0581 - dense_13_loss: 0.0986 - dense_14_loss: 0.1008 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9869 - dense_14_categorical_accuracy: 0.9852 - val_loss: 0.6882 - val_lambda_5_loss: 0.0372 - val_dense_13_loss: 0.1591 - val_dense_14_loss: 0.1584 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9605 - val_dense_14_categorical_accuracy: 0.9605
# Epoch 39/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.9378 - lambda_5_loss: 0.0673 - dense_13_loss: 0.1324 - dense_14_loss: 0.1322 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9765 - dense_14_categorical_accuracy: 0.9760 - val_loss: 0.6343 - val_lambda_5_loss: 0.0370 - val_dense_13_loss: 0.1299 - val_dense_14_loss: 0.1328 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9707 - val_dense_14_categorical_accuracy: 0.9720
# Epoch 40/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.7196 - lambda_5_loss: 0.0557 - dense_13_loss: 0.0810 - dense_14_loss: 0.0818 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9931 - dense_14_categorical_accuracy: 0.9905 - val_loss: 0.4987 - val_lambda_5_loss: 0.0274 - val_dense_13_loss: 0.1114 - val_dense_14_loss: 0.1113 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9771 - val_dense_14_categorical_accuracy: 0.9781
# Epoch 41/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.7349 - lambda_5_loss: 0.0573 - dense_13_loss: 0.0822 - dense_14_loss: 0.0800 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9917 - dense_14_categorical_accuracy: 0.9915 - val_loss: 0.5073 - val_lambda_5_loss: 0.0282 - val_dense_13_loss: 0.1113 - val_dense_14_loss: 0.1123 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9758 - val_dense_14_categorical_accuracy: 0.9750
# Epoch 42/150
# 8120/8120 [==============================] - 50s 6ms/sample - loss: 0.6932 - lambda_5_loss: 0.0543 - dense_13_loss: 0.0746 - dense_14_loss: 0.0752 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9917 - dense_14_categorical_accuracy: 0.9945 - val_loss: 0.5130 - val_lambda_5_loss: 0.0291 - val_dense_13_loss: 0.1085 - val_dense_14_loss: 0.1116 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9788 - val_dense_14_categorical_accuracy: 0.9779
# Epoch 43/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.6854 - lambda_5_loss: 0.0543 - dense_13_loss: 0.0710 - dense_14_loss: 0.0711 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9942 - dense_14_categorical_accuracy: 0.9929 - val_loss: 0.4964 - val_lambda_5_loss: 0.0289 - val_dense_13_loss: 0.1013 - val_dense_14_loss: 0.1045 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9801 - val_dense_14_categorical_accuracy: 0.9796
# Epoch 44/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.7416 - lambda_5_loss: 0.0583 - dense_13_loss: 0.0837 - dense_14_loss: 0.0745 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9900 - dense_14_categorical_accuracy: 0.9898 - val_loss: 0.6967 - val_lambda_5_loss: 0.0384 - val_dense_13_loss: 0.1557 - val_dense_14_loss: 0.1552 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9639 - val_dense_14_categorical_accuracy: 0.9639
# Epoch 45/150
# 8120/8120 [==============================] - 50s 6ms/sample - loss: 0.6820 - lambda_5_loss: 0.0545 - dense_13_loss: 0.0694 - dense_14_loss: 0.0677 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9931 - dense_14_categorical_accuracy: 0.9926 - val_loss: 0.5348 - val_lambda_5_loss: 0.0305 - val_dense_13_loss: 0.1143 - val_dense_14_loss: 0.1140 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9767 - val_dense_14_categorical_accuracy: 0.9769
# Epoch 46/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.6590 - lambda_5_loss: 0.0531 - dense_13_loss: 0.0635 - dense_14_loss: 0.0647 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9930 - dense_14_categorical_accuracy: 0.9936 - val_loss: 0.4762 - val_lambda_5_loss: 0.0275 - val_dense_13_loss: 0.0980 - val_dense_14_loss: 0.1023 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9813 - val_dense_14_categorical_accuracy: 0.9803
# Epoch 47/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.6610 - lambda_5_loss: 0.0535 - dense_13_loss: 0.0634 - dense_14_loss: 0.0627 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9940 - dense_14_categorical_accuracy: 0.9931 - val_loss: 0.5141 - val_lambda_5_loss: 0.0294 - val_dense_13_loss: 0.1078 - val_dense_14_loss: 0.1109 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9762 - val_dense_14_categorical_accuracy: 0.9754
# Epoch 48/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.6671 - lambda_5_loss: 0.0540 - dense_13_loss: 0.0636 - dense_14_loss: 0.0636 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9930 - dense_14_categorical_accuracy: 0.9917 - val_loss: 0.5694 - val_lambda_5_loss: 0.0321 - val_dense_13_loss: 0.1219 - val_dense_14_loss: 0.1250 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9728 - val_dense_14_categorical_accuracy: 0.9722
# Epoch 49/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.6407 - lambda_5_loss: 0.0525 - dense_13_loss: 0.0568 - dense_14_loss: 0.0587 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9959 - dense_14_categorical_accuracy: 0.9937 - val_loss: 0.5279 - val_lambda_5_loss: 0.0307 - val_dense_13_loss: 0.1090 - val_dense_14_loss: 0.1102 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9775 - val_dense_14_categorical_accuracy: 0.9773
# Epoch 50/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.6608 - lambda_5_loss: 0.0543 - dense_13_loss: 0.0593 - dense_14_loss: 0.0580 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9933 - dense_14_categorical_accuracy: 0.9943 - val_loss: 0.5201 - val_lambda_5_loss: 0.0299 - val_dense_13_loss: 0.1091 - val_dense_14_loss: 0.1108 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9767 - val_dense_14_categorical_accuracy: 0.9767
# Epoch 51/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.7814 - lambda_5_loss: 0.0600 - dense_13_loss: 0.0949 - dense_14_loss: 0.0866 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9821 - dense_14_categorical_accuracy: 0.9847 - val_loss: 0.5596 - val_lambda_5_loss: 0.0305 - val_dense_13_loss: 0.1248 - val_dense_14_loss: 0.1277 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9711 - val_dense_14_categorical_accuracy: 0.9705
# Epoch 52/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.7995 - lambda_5_loss: 0.0616 - dense_13_loss: 0.0949 - dense_14_loss: 0.0888 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9804 - dense_14_categorical_accuracy: 0.9825 - val_loss: 0.5213 - val_lambda_5_loss: 0.0307 - val_dense_13_loss: 0.1026 - val_dense_14_loss: 0.1102 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9767 - val_dense_14_categorical_accuracy: 0.9754
# Epoch 53/150
# 8120/8120 [==============================] - 53s 6ms/sample - loss: 0.6967 - lambda_5_loss: 0.0574 - dense_13_loss: 0.0657 - dense_14_loss: 0.0573 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9910 - dense_14_categorical_accuracy: 0.9935 - val_loss: 0.5580 - val_lambda_5_loss: 0.0315 - val_dense_13_loss: 0.1166 - val_dense_14_loss: 0.1248 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9741 - val_dense_14_categorical_accuracy: 0.9724
# Epoch 54/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.7362 - lambda_5_loss: 0.0588 - dense_13_loss: 0.0739 - dense_14_loss: 0.0746 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9881 - dense_14_categorical_accuracy: 0.9876 - val_loss: 0.6435 - val_lambda_5_loss: 0.0378 - val_dense_13_loss: 0.1299 - val_dense_14_loss: 0.1337 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9720 - val_dense_14_categorical_accuracy: 0.9713
# Epoch 55/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.7878 - lambda_5_loss: 0.0604 - dense_13_loss: 0.0908 - dense_14_loss: 0.0930 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9820 - dense_14_categorical_accuracy: 0.9828 - val_loss: 0.5687 - val_lambda_5_loss: 0.0313 - val_dense_13_loss: 0.1226 - val_dense_14_loss: 0.1311 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9690 - val_dense_14_categorical_accuracy: 0.9669
# Epoch 56/150
# 8120/8120 [==============================] - 53s 6ms/sample - loss: 0.6865 - lambda_5_loss: 0.0558 - dense_13_loss: 0.0653 - dense_14_loss: 0.0630 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9905 - dense_14_categorical_accuracy: 0.9909 - val_loss: 0.6237 - val_lambda_5_loss: 0.0358 - val_dense_13_loss: 0.1295 - val_dense_14_loss: 0.1342 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9703 - val_dense_14_categorical_accuracy: 0.9684
# Epoch 57/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.6431 - lambda_5_loss: 0.0533 - dense_13_loss: 0.0541 - dense_14_loss: 0.0555 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9931 - dense_14_categorical_accuracy: 0.9920 - val_loss: 0.7225 - val_lambda_5_loss: 0.0426 - val_dense_13_loss: 0.1479 - val_dense_14_loss: 0.1465 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9690 - val_dense_14_categorical_accuracy: 0.9694
# Epoch 58/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.7390 - lambda_5_loss: 0.0579 - dense_13_loss: 0.0795 - dense_14_loss: 0.0803 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9867 - dense_14_categorical_accuracy: 0.9841 - val_loss: 0.8174 - val_lambda_5_loss: 0.0490 - val_dense_13_loss: 0.1620 - val_dense_14_loss: 0.1624 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9601 - val_dense_14_categorical_accuracy: 0.9614
# Epoch 59/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.6467 - lambda_5_loss: 0.0530 - dense_13_loss: 0.0595 - dense_14_loss: 0.0579 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9899 - dense_14_categorical_accuracy: 0.9901 - val_loss: 0.8305 - val_lambda_5_loss: 0.0449 - val_dense_13_loss: 0.1893 - val_dense_14_loss: 0.1890 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9571 - val_dense_14_categorical_accuracy: 0.9569
# Epoch 60/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.6640 - lambda_5_loss: 0.0540 - dense_13_loss: 0.0626 - dense_14_loss: 0.0609 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9900 - dense_14_categorical_accuracy: 0.9895 - val_loss: 0.6246 - val_lambda_5_loss: 0.0361 - val_dense_13_loss: 0.1290 - val_dense_14_loss: 0.1320 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9686 - val_dense_14_categorical_accuracy: 0.9682
# Epoch 61/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.6127 - lambda_5_loss: 0.0516 - dense_13_loss: 0.0485 - dense_14_loss: 0.0482 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9930 - dense_14_categorical_accuracy: 0.9925 - val_loss: 0.6085 - val_lambda_5_loss: 0.0325 - val_dense_13_loss: 0.1370 - val_dense_14_loss: 0.1445 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9716 - val_dense_14_categorical_accuracy: 0.9699
# Epoch 62/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.6035 - lambda_5_loss: 0.0512 - dense_13_loss: 0.0429 - dense_14_loss: 0.0491 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9942 - dense_14_categorical_accuracy: 0.9919 - val_loss: 0.5372 - val_lambda_5_loss: 0.0303 - val_dense_13_loss: 0.1144 - val_dense_14_loss: 0.1179 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9733 - val_dense_14_categorical_accuracy: 0.9720
# Epoch 63/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.6148 - lambda_5_loss: 0.0522 - dense_13_loss: 0.0450 - dense_14_loss: 0.0476 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9937 - dense_14_categorical_accuracy: 0.9930 - val_loss: 0.7212 - val_lambda_5_loss: 0.0415 - val_dense_13_loss: 0.1500 - val_dense_14_loss: 0.1538 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9669 - val_dense_14_categorical_accuracy: 0.9669
# Epoch 64/150
# 8120/8120 [==============================] - 58s 7ms/sample - loss: 0.7618 - lambda_5_loss: 0.0595 - dense_13_loss: 0.0795 - dense_14_loss: 0.0874 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9847 - dense_14_categorical_accuracy: 0.9837 - val_loss: 0.8644 - val_lambda_5_loss: 0.0473 - val_dense_13_loss: 0.1956 - val_dense_14_loss: 0.1931 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9554 - val_dense_14_categorical_accuracy: 0.9571
# Epoch 65/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.7055 - lambda_5_loss: 0.0565 - dense_13_loss: 0.0658 - dense_14_loss: 0.0747 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9867 - dense_14_categorical_accuracy: 0.9846 - val_loss: 0.5206 - val_lambda_5_loss: 0.0303 - val_dense_13_loss: 0.1073 - val_dense_14_loss: 0.1089 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9728 - val_dense_14_categorical_accuracy: 0.9737
# Epoch 66/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.6172 - lambda_5_loss: 0.0524 - dense_13_loss: 0.0431 - dense_14_loss: 0.0498 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9935 - dense_14_categorical_accuracy: 0.9917 - val_loss: 0.6047 - val_lambda_5_loss: 0.0351 - val_dense_13_loss: 0.1258 - val_dense_14_loss: 0.1257 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9733 - val_dense_14_categorical_accuracy: 0.9733
# Epoch 67/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.5918 - lambda_5_loss: 0.0509 - dense_13_loss: 0.0428 - dense_14_loss: 0.0396 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9926 - dense_14_categorical_accuracy: 0.9943 - val_loss: 0.6078 - val_lambda_5_loss: 0.0341 - val_dense_13_loss: 0.1325 - val_dense_14_loss: 0.1327 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9724 - val_dense_14_categorical_accuracy: 0.9724
# Epoch 68/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.5976 - lambda_5_loss: 0.0515 - dense_13_loss: 0.0411 - dense_14_loss: 0.0415 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9931 - dense_14_categorical_accuracy: 0.9951 - val_loss: 0.6314 - val_lambda_5_loss: 0.0352 - val_dense_13_loss: 0.1378 - val_dense_14_loss: 0.1394 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9699 - val_dense_14_categorical_accuracy: 0.9697
# Epoch 69/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.5914 - lambda_5_loss: 0.0508 - dense_13_loss: 0.0425 - dense_14_loss: 0.0406 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9935 - dense_14_categorical_accuracy: 0.9940 - val_loss: 0.6250 - val_lambda_5_loss: 0.0353 - val_dense_13_loss: 0.1339 - val_dense_14_loss: 0.1364 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9711 - val_dense_14_categorical_accuracy: 0.9711
# Epoch 70/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.6161 - lambda_5_loss: 0.0531 - dense_13_loss: 0.0441 - dense_14_loss: 0.0411 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9919 - dense_14_categorical_accuracy: 0.9937 - val_loss: 0.6132 - val_lambda_5_loss: 0.0345 - val_dense_13_loss: 0.1317 - val_dense_14_loss: 0.1349 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9703 - val_dense_14_categorical_accuracy: 0.9701
# Epoch 71/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5981 - lambda_5_loss: 0.0521 - dense_13_loss: 0.0363 - dense_14_loss: 0.0412 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9956 - dense_14_categorical_accuracy: 0.9941 - val_loss: 0.6142 - val_lambda_5_loss: 0.0340 - val_dense_13_loss: 0.1358 - val_dense_14_loss: 0.1366 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9703 - val_dense_14_categorical_accuracy: 0.9707
# Epoch 72/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.5775 - lambda_5_loss: 0.0497 - dense_13_loss: 0.0380 - dense_14_loss: 0.0427 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9946 - dense_14_categorical_accuracy: 0.9929 - val_loss: 0.5835 - val_lambda_5_loss: 0.0327 - val_dense_13_loss: 0.1257 - val_dense_14_loss: 0.1285 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9750 - val_dense_14_categorical_accuracy: 0.9750
# Epoch 73/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.5890 - lambda_5_loss: 0.0511 - dense_13_loss: 0.0361 - dense_14_loss: 0.0419 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9938 - dense_14_categorical_accuracy: 0.9929 - val_loss: 0.5934 - val_lambda_5_loss: 0.0330 - val_dense_13_loss: 0.1294 - val_dense_14_loss: 0.1326 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9733 - val_dense_14_categorical_accuracy: 0.9728
# Epoch 74/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.5979 - lambda_5_loss: 0.0517 - dense_13_loss: 0.0394 - dense_14_loss: 0.0411 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9945 - dense_14_categorical_accuracy: 0.9927 - val_loss: 0.5696 - val_lambda_5_loss: 0.0327 - val_dense_13_loss: 0.1190 - val_dense_14_loss: 0.1215 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9767 - val_dense_14_categorical_accuracy: 0.9760
# Epoch 75/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.5945 - lambda_5_loss: 0.0516 - dense_13_loss: 0.0408 - dense_14_loss: 0.0380 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9936 - dense_14_categorical_accuracy: 0.9929 - val_loss: 0.6382 - val_lambda_5_loss: 0.0366 - val_dense_13_loss: 0.1347 - val_dense_14_loss: 0.1364 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9711 - val_dense_14_categorical_accuracy: 0.9716
# Epoch 76/150
# 8120/8120 [==============================] - 55s 7ms/sample - loss: 0.5944 - lambda_5_loss: 0.0515 - dense_13_loss: 0.0381 - dense_14_loss: 0.0413 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9950 - dense_14_categorical_accuracy: 0.9935 - val_loss: 0.6894 - val_lambda_5_loss: 0.0377 - val_dense_13_loss: 0.1543 - val_dense_14_loss: 0.1552 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9707 - val_dense_14_categorical_accuracy: 0.9707
# Epoch 77/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5973 - lambda_5_loss: 0.0519 - dense_13_loss: 0.0408 - dense_14_loss: 0.0376 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9927 - dense_14_categorical_accuracy: 0.9943 - val_loss: 0.6676 - val_lambda_5_loss: 0.0358 - val_dense_13_loss: 0.1514 - val_dense_14_loss: 0.1558 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9733
# Epoch 78/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.6688 - lambda_5_loss: 0.0560 - dense_13_loss: 0.0551 - dense_14_loss: 0.0537 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9913 - dense_14_categorical_accuracy: 0.9900 - val_loss: 0.6224 - val_lambda_5_loss: 0.0336 - val_dense_13_loss: 0.1405 - val_dense_14_loss: 0.1440 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9730
# Epoch 79/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5887 - lambda_5_loss: 0.0516 - dense_13_loss: 0.0378 - dense_14_loss: 0.0347 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9942 - dense_14_categorical_accuracy: 0.9947 - val_loss: 0.6306 - val_lambda_5_loss: 0.0352 - val_dense_13_loss: 0.1367 - val_dense_14_loss: 0.1404 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9745 - val_dense_14_categorical_accuracy: 0.9739
# Epoch 80/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.6008 - lambda_5_loss: 0.0525 - dense_13_loss: 0.0389 - dense_14_loss: 0.0369 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9938 - dense_14_categorical_accuracy: 0.9941 - val_loss: 0.6607 - val_lambda_5_loss: 0.0360 - val_dense_13_loss: 0.1453 - val_dense_14_loss: 0.1533 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9711 - val_dense_14_categorical_accuracy: 0.9701
# Epoch 81/150
# 8120/8120 [==============================] - 53s 6ms/sample - loss: 0.6258 - lambda_5_loss: 0.0539 - dense_13_loss: 0.0435 - dense_14_loss: 0.0436 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9925 - dense_14_categorical_accuracy: 0.9914 - val_loss: 0.6527 - val_lambda_5_loss: 0.0356 - val_dense_13_loss: 0.1449 - val_dense_14_loss: 0.1498 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9720 - val_dense_14_categorical_accuracy: 0.9713
# Epoch 82/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5835 - lambda_5_loss: 0.0511 - dense_13_loss: 0.0366 - dense_14_loss: 0.0352 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9933 - dense_14_categorical_accuracy: 0.9945 - val_loss: 0.6448 - val_lambda_5_loss: 0.0355 - val_dense_13_loss: 0.1413 - val_dense_14_loss: 0.1464 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9733 - val_dense_14_categorical_accuracy: 0.9726
# Epoch 83/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5807 - lambda_5_loss: 0.0511 - dense_13_loss: 0.0361 - dense_14_loss: 0.0340 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9929 - dense_14_categorical_accuracy: 0.9946 - val_loss: 0.5941 - val_lambda_5_loss: 0.0332 - val_dense_13_loss: 0.1277 - val_dense_14_loss: 0.1322 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9758 - val_dense_14_categorical_accuracy: 0.9752
# Epoch 84/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5629 - lambda_5_loss: 0.0496 - dense_13_loss: 0.0346 - dense_14_loss: 0.0323 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9951 - dense_14_categorical_accuracy: 0.9958 - val_loss: 0.6166 - val_lambda_5_loss: 0.0330 - val_dense_13_loss: 0.1406 - val_dense_14_loss: 0.1441 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9745 - val_dense_14_categorical_accuracy: 0.9743
# Epoch 85/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5708 - lambda_5_loss: 0.0499 - dense_13_loss: 0.0374 - dense_14_loss: 0.0344 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9931 - dense_14_categorical_accuracy: 0.9940 - val_loss: 0.5872 - val_lambda_5_loss: 0.0318 - val_dense_13_loss: 0.1315 - val_dense_14_loss: 0.1354 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9762 - val_dense_14_categorical_accuracy: 0.9758
# Epoch 86/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.5751 - lambda_5_loss: 0.0510 - dense_13_loss: 0.0325 - dense_14_loss: 0.0331 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9954 - dense_14_categorical_accuracy: 0.9953 - val_loss: 0.6062 - val_lambda_5_loss: 0.0340 - val_dense_13_loss: 0.1294 - val_dense_14_loss: 0.1354 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9758 - val_dense_14_categorical_accuracy: 0.9750
# Epoch 87/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5703 - lambda_5_loss: 0.0503 - dense_13_loss: 0.0345 - dense_14_loss: 0.0324 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9946 - dense_14_categorical_accuracy: 0.9951 - val_loss: 0.6120 - val_lambda_5_loss: 0.0342 - val_dense_13_loss: 0.1300 - val_dense_14_loss: 0.1380 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9758 - val_dense_14_categorical_accuracy: 0.9750
# Epoch 88/150
# 8120/8120 [==============================] - 57s 7ms/sample - loss: 0.5739 - lambda_5_loss: 0.0506 - dense_13_loss: 0.0342 - dense_14_loss: 0.0332 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9938 - dense_14_categorical_accuracy: 0.9940 - val_loss: 0.5968 - val_lambda_5_loss: 0.0324 - val_dense_13_loss: 0.1327 - val_dense_14_loss: 0.1379 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9767 - val_dense_14_categorical_accuracy: 0.9764
# Epoch 89/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.5631 - lambda_5_loss: 0.0498 - dense_13_loss: 0.0316 - dense_14_loss: 0.0335 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9948 - dense_14_categorical_accuracy: 0.9931 - val_loss: 0.5890 - val_lambda_5_loss: 0.0324 - val_dense_13_loss: 0.1297 - val_dense_14_loss: 0.1334 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9762 - val_dense_14_categorical_accuracy: 0.9756
# Epoch 90/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5696 - lambda_5_loss: 0.0505 - dense_13_loss: 0.0337 - dense_14_loss: 0.0303 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9936 - dense_14_categorical_accuracy: 0.9948 - val_loss: 0.6650 - val_lambda_5_loss: 0.0365 - val_dense_13_loss: 0.1495 - val_dense_14_loss: 0.1484 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9724 - val_dense_14_categorical_accuracy: 0.9722
# Epoch 91/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.5751 - lambda_5_loss: 0.0506 - dense_13_loss: 0.0330 - dense_14_loss: 0.0365 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9935 - dense_14_categorical_accuracy: 0.9938 - val_loss: 0.6073 - val_lambda_5_loss: 0.0332 - val_dense_13_loss: 0.1358 - val_dense_14_loss: 0.1373 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9758 - val_dense_14_categorical_accuracy: 0.9758
# Epoch 92/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5686 - lambda_5_loss: 0.0502 - dense_13_loss: 0.0338 - dense_14_loss: 0.0326 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9927 - dense_14_categorical_accuracy: 0.9940 - val_loss: 0.5960 - val_lambda_5_loss: 0.0329 - val_dense_13_loss: 0.1304 - val_dense_14_loss: 0.1348 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9771 - val_dense_14_categorical_accuracy: 0.9769
# Epoch 93/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5649 - lambda_5_loss: 0.0503 - dense_13_loss: 0.0305 - dense_14_loss: 0.0312 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9947 - dense_14_categorical_accuracy: 0.9952 - val_loss: 0.6132 - val_lambda_5_loss: 0.0342 - val_dense_13_loss: 0.1332 - val_dense_14_loss: 0.1361 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9767 - val_dense_14_categorical_accuracy: 0.9767
# Epoch 94/150
# ...
# Epoch 121/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.5578 - lambda_5_loss: 0.0499 - dense_13_loss: 0.0297 - dense_14_loss: 0.0292 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9946 - dense_14_categorical_accuracy: 0.9942 - val_loss: 0.6353 - val_lambda_5_loss: 0.0343 - val_dense_13_loss: 0.1432 - val_dense_14_loss: 0.1468 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9762 - val_dense_14_categorical_accuracy: 0.9764
# Epoch 122/150
# 8120/8120 [==============================] - 53s 6ms/sample - loss: 0.5493 - lambda_5_loss: 0.0490 - dense_13_loss: 0.0272 - dense_14_loss: 0.0324 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9951 - dense_14_categorical_accuracy: 0.9925 - val_loss: 0.6424 - val_lambda_5_loss: 0.0345 - val_dense_13_loss: 0.1455 - val_dense_14_loss: 0.1503 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9733 - val_dense_14_categorical_accuracy: 0.9728
# Epoch 123/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.5531 - lambda_5_loss: 0.0496 - dense_13_loss: 0.0272 - dense_14_loss: 0.0302 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9943 - dense_14_categorical_accuracy: 0.9942 - val_loss: 0.7409 - val_lambda_5_loss: 0.0379 - val_dense_13_loss: 0.1778 - val_dense_14_loss: 0.1819 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9703 - val_dense_14_categorical_accuracy: 0.9692
# Epoch 124/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5748 - lambda_5_loss: 0.0515 - dense_13_loss: 0.0290 - dense_14_loss: 0.0307 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9952 - dense_14_categorical_accuracy: 0.9937 - val_loss: 0.7046 - val_lambda_5_loss: 0.0367 - val_dense_13_loss: 0.1669 - val_dense_14_loss: 0.1682 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9716 - val_dense_14_categorical_accuracy: 0.9711
# Epoch 125/150
# 8120/8120 [==============================] - 53s 7ms/sample - loss: 0.5657 - lambda_5_loss: 0.0507 - dense_13_loss: 0.0283 - dense_14_loss: 0.0302 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9947 - dense_14_categorical_accuracy: 0.9931 - val_loss: 0.6585 - val_lambda_5_loss: 0.0354 - val_dense_13_loss: 0.1507 - val_dense_14_loss: 0.1518 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9737
# Epoch 126/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.5458 - lambda_5_loss: 0.0493 - dense_13_loss: 0.0249 - dense_14_loss: 0.0285 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9958 - dense_14_categorical_accuracy: 0.9942 - val_loss: 0.6385 - val_lambda_5_loss: 0.0339 - val_dense_13_loss: 0.1446 - val_dense_14_loss: 0.1528 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9741 - val_dense_14_categorical_accuracy: 0.9730
# Epoch 127/150
# 8120/8120 [==============================] - 55s 7ms/sample - loss: 0.5632 - lambda_5_loss: 0.0503 - dense_13_loss: 0.0303 - dense_14_loss: 0.0300 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9943 - dense_14_categorical_accuracy: 0.9936 - val_loss: 0.6360 - val_lambda_5_loss: 0.0344 - val_dense_13_loss: 0.1439 - val_dense_14_loss: 0.1465 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9762 - val_dense_14_categorical_accuracy: 0.9764
# Epoch 128/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5756 - lambda_5_loss: 0.0516 - dense_13_loss: 0.0311 - dense_14_loss: 0.0289 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9937 - dense_14_categorical_accuracy: 0.9945 - val_loss: 0.6410 - val_lambda_5_loss: 0.0347 - val_dense_13_loss: 0.1446 - val_dense_14_loss: 0.1472 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9754 - val_dense_14_categorical_accuracy: 0.9754
# Epoch 129/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5781 - lambda_5_loss: 0.0516 - dense_13_loss: 0.0316 - dense_14_loss: 0.0303 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9926 - dense_14_categorical_accuracy: 0.9932 - val_loss: 0.6842 - val_lambda_5_loss: 0.0364 - val_dense_13_loss: 0.1580 - val_dense_14_loss: 0.1605 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9733
# Epoch 130/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5666 - lambda_5_loss: 0.0507 - dense_13_loss: 0.0295 - dense_14_loss: 0.0298 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9938 - dense_14_categorical_accuracy: 0.9943 - val_loss: 0.6643 - val_lambda_5_loss: 0.0353 - val_dense_13_loss: 0.1534 - val_dense_14_loss: 0.1559 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9733
# Epoch 131/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.5541 - lambda_5_loss: 0.0498 - dense_13_loss: 0.0275 - dense_14_loss: 0.0289 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9942 - dense_14_categorical_accuracy: 0.9942 - val_loss: 0.6385 - val_lambda_5_loss: 0.0343 - val_dense_13_loss: 0.1429 - val_dense_14_loss: 0.1510 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9733 - val_dense_14_categorical_accuracy: 0.9733
# Epoch 132/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5521 - lambda_5_loss: 0.0492 - dense_13_loss: 0.0307 - dense_14_loss: 0.0289 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9932 - dense_14_categorical_accuracy: 0.9938 - val_loss: 0.6408 - val_lambda_5_loss: 0.0344 - val_dense_13_loss: 0.1457 - val_dense_14_loss: 0.1495 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9754 - val_dense_14_categorical_accuracy: 0.9752
# Epoch 133/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.5623 - lambda_5_loss: 0.0504 - dense_13_loss: 0.0281 - dense_14_loss: 0.0300 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9938 - dense_14_categorical_accuracy: 0.9940 - val_loss: 0.6698 - val_lambda_5_loss: 0.0354 - val_dense_13_loss: 0.1548 - val_dense_14_loss: 0.1586 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9730
# Epoch 134/150
# 8120/8120 [==============================] - 51s 6ms/sample - loss: 0.5960 - lambda_5_loss: 0.0531 - dense_13_loss: 0.0326 - dense_14_loss: 0.0324 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9920 - dense_14_categorical_accuracy: 0.9938 - val_loss: 0.6756 - val_lambda_5_loss: 0.0358 - val_dense_13_loss: 0.1562 - val_dense_14_loss: 0.1593 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9733 - val_dense_14_categorical_accuracy: 0.9728
# Epoch 135/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5784 - lambda_5_loss: 0.0513 - dense_13_loss: 0.0326 - dense_14_loss: 0.0328 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9931 - dense_14_categorical_accuracy: 0.9932 - val_loss: 0.6679 - val_lambda_5_loss: 0.0355 - val_dense_13_loss: 0.1541 - val_dense_14_loss: 0.1568 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9735
# Epoch 136/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5818 - lambda_5_loss: 0.0518 - dense_13_loss: 0.0307 - dense_14_loss: 0.0331 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9926 - dense_14_categorical_accuracy: 0.9930 - val_loss: 0.7442 - val_lambda_5_loss: 0.0384 - val_dense_13_loss: 0.1762 - val_dense_14_loss: 0.1816 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9707 - val_dense_14_categorical_accuracy: 0.9701
# Epoch 137/150
# 8120/8120 [==============================] - 50s 6ms/sample - loss: 0.5829 - lambda_5_loss: 0.0520 - dense_13_loss: 0.0310 - dense_14_loss: 0.0324 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9942 - dense_14_categorical_accuracy: 0.9930 - val_loss: 0.6799 - val_lambda_5_loss: 0.0358 - val_dense_13_loss: 0.1573 - val_dense_14_loss: 0.1628 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9728
# Epoch 138/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5516 - lambda_5_loss: 0.0497 - dense_13_loss: 0.0254 - dense_14_loss: 0.0291 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9953 - dense_14_categorical_accuracy: 0.9945 - val_loss: 0.6815 - val_lambda_5_loss: 0.0357 - val_dense_13_loss: 0.1585 - val_dense_14_loss: 0.1637 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9728
# Epoch 139/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5773 - lambda_5_loss: 0.0512 - dense_13_loss: 0.0350 - dense_14_loss: 0.0309 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9919 - dense_14_categorical_accuracy: 0.9930 - val_loss: 0.6961 - val_lambda_5_loss: 0.0365 - val_dense_13_loss: 0.1624 - val_dense_14_loss: 0.1661 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9724 - val_dense_14_categorical_accuracy: 0.9718
# Epoch 140/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5638 - lambda_5_loss: 0.0508 - dense_13_loss: 0.0289 - dense_14_loss: 0.0271 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9940 - dense_14_categorical_accuracy: 0.9945 - val_loss: 0.7026 - val_lambda_5_loss: 0.0365 - val_dense_13_loss: 0.1663 - val_dense_14_loss: 0.1685 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9724 - val_dense_14_categorical_accuracy: 0.9716
# Epoch 141/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5501 - lambda_5_loss: 0.0490 - dense_13_loss: 0.0294 - dense_14_loss: 0.0309 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9933 - dense_14_categorical_accuracy: 0.9941 - val_loss: 0.6644 - val_lambda_5_loss: 0.0347 - val_dense_13_loss: 0.1567 - val_dense_14_loss: 0.1583 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9737
# Epoch 142/150
# 8120/8120 [==============================] - 53s 6ms/sample - loss: 0.5814 - lambda_5_loss: 0.0519 - dense_13_loss: 0.0299 - dense_14_loss: 0.0326 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9935 - dense_14_categorical_accuracy: 0.9937 - val_loss: 0.7950 - val_lambda_5_loss: 0.0403 - val_dense_13_loss: 0.1920 - val_dense_14_loss: 0.1975 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9682 - val_dense_14_categorical_accuracy: 0.9675
# Epoch 143/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5791 - lambda_5_loss: 0.0520 - dense_13_loss: 0.0272 - dense_14_loss: 0.0323 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9948 - dense_14_categorical_accuracy: 0.9931 - val_loss: 0.6982 - val_lambda_5_loss: 0.0368 - val_dense_13_loss: 0.1622 - val_dense_14_loss: 0.1658 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9724 - val_dense_14_categorical_accuracy: 0.9713
# Epoch 144/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5665 - lambda_5_loss: 0.0506 - dense_13_loss: 0.0283 - dense_14_loss: 0.0318 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9941 - dense_14_categorical_accuracy: 0.9930 - val_loss: 0.6557 - val_lambda_5_loss: 0.0352 - val_dense_13_loss: 0.1497 - val_dense_14_loss: 0.1521 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9745 - val_dense_14_categorical_accuracy: 0.9750
# Epoch 145/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5553 - lambda_5_loss: 0.0497 - dense_13_loss: 0.0263 - dense_14_loss: 0.0322 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9948 - dense_14_categorical_accuracy: 0.9942 - val_loss: 0.6811 - val_lambda_5_loss: 0.0356 - val_dense_13_loss: 0.1593 - val_dense_14_loss: 0.1634 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9733 - val_dense_14_categorical_accuracy: 0.9716
# Epoch 146/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5587 - lambda_5_loss: 0.0500 - dense_13_loss: 0.0321 - dense_14_loss: 0.0261 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9938 - dense_14_categorical_accuracy: 0.9947 - val_loss: 0.6619 - val_lambda_5_loss: 0.0348 - val_dense_13_loss: 0.1544 - val_dense_14_loss: 0.1571 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9737
# Epoch 147/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5585 - lambda_5_loss: 0.0502 - dense_13_loss: 0.0259 - dense_14_loss: 0.0303 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9952 - dense_14_categorical_accuracy: 0.9945 - val_loss: 0.7010 - val_lambda_5_loss: 0.0364 - val_dense_13_loss: 0.1685 - val_dense_14_loss: 0.1666 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9711 - val_dense_14_categorical_accuracy: 0.9711
# Epoch 148/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5491 - lambda_5_loss: 0.0494 - dense_13_loss: 0.0291 - dense_14_loss: 0.0265 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9947 - dense_14_categorical_accuracy: 0.9950 - val_loss: 0.6625 - val_lambda_5_loss: 0.0347 - val_dense_13_loss: 0.1562 - val_dense_14_loss: 0.1575 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9737 - val_dense_14_categorical_accuracy: 0.9730
# Epoch 149/150
# 8120/8120 [==============================] - 52s 6ms/sample - loss: 0.5412 - lambda_5_loss: 0.0481 - dense_13_loss: 0.0320 - dense_14_loss: 0.0279 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9932 - dense_14_categorical_accuracy: 0.9945 - val_loss: 0.6604 - val_lambda_5_loss: 0.0345 - val_dense_13_loss: 0.1556 - val_dense_14_loss: 0.1573 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9733 - val_dense_14_categorical_accuracy: 0.9730
# Epoch 150/150
# 8120/8120 [==============================] - 54s 7ms/sample - loss: 0.5552 - lambda_5_loss: 0.0500 - dense_13_loss: 0.0282 - dense_14_loss: 0.0276 - lambda_5_categorical_accuracy: 1.0000 - dense_13_categorical_accuracy: 0.9941 - dense_14_categorical_accuracy: 0.9945 - val_loss: 0.6611 - val_lambda_5_loss: 0.0346 - val_dense_13_loss: 0.1557 - val_dense_14_loss: 0.1570 - val_lambda_5_categorical_accuracy: 1.0000 - val_dense_13_categorical_accuracy: 0.9733 - val_dense_14_categorical_accuracy: 0.9730
# Saved model to disk

# %%
siamese= Bearings_Network(type_net="Siamese", base_network = pretrain.base_network)

siamese.load_weights(filepath = "Weights/Siamese/Siamese.h5", filepath_base = "Weights/Siamese/Siamese_base.h5")
# Out:
# Creating  Siamese  Network
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %% [markdown]
# Create Test data

# %%
#Test
testX0 = np.expand_dims(X_test, axis=2)

y_pred = siamese.model.predict([testX0,testX0])[1]

# %% [markdown]
# Check accuracy + confusion matrix

# %%
matrix = metrics.confusion_matrix(y_test, y_pred.argmax(axis=1))
print("Confusion matrix: \n" + str(matrix))
print("Accuracy: " + str(np.sum(np.diag(matrix))/np.sum(matrix)))
# Out:
# Confusion matrix:
# [[719  31   0   0]
#  [ 45 945   0   0]
#  [  1   0 704   0]
#  [  0   4   0 586]]
# Accuracy: 0.9733113673805601

# %% [markdown]
# The accuracy of the model has improved when using the contrastive loss to generate embeddings. This means having good embeddings helps the model to classify better.

# %% [markdown]
# ### Visualize features using UMAP
#
# Finally, we visualize again the features extracted by the model after training the embeddings with contrastive loss.

# %%
features = siamese.base_network.predict(testX0)

embedding = umap.UMAP(n_neighbors=10,
                      min_dist=0.8,
                      metric='correlation').fit_transform(features)

color = pd.DataFrame(y_test,columns=['color'])
color.replace({0:'red', 1:'blue', 2:'green', 3:'purple'},inplace=True)


fig, ax = plt.subplots(figsize=(10, 8))
plt.scatter(embedding[:,0], embedding[:,1], 
            c=color.values.flatten(),
            cmap="Spectral", 
            s=1.0)
plt.setp(ax, xticks=[], yticks=[])
plt.title("Extracted features classification model", fontsize=18)

plt.show()
# Out:
# C:\Users\laia.domingo.colomer\AppData\Local\Continuum\anaconda3\lib\site-packages\umap\spectral.py:229: UserWarning:
#
# Embedding a total of 5 separate connected components using meta-embedding (experimental)

# %% [markdown]
# Observe that after training with the contrastive loss, the embeddings seem to differentiate better the failure modes.
